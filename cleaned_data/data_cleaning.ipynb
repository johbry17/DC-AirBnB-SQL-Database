# %%
# import dependencies
import pandas as pd
import numpy as np

# %%
# import os

# # Change the current working directory to the one containing the 'raw_data' folder
# os.chdir('C:/Users/johbr/Data-Analyst/Projects/DC-AirBnB-SQL-Database')

# # Now, try reading the file again
# df = pd.read_csv("./raw_data/listings_2024_mar.csv")
# df.head()

# %%
# read in listings data
df = pd.read_csv("../raw_data/listings_2024_mar.csv")
df.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  3686  https://www.airbnb.com/rooms/3686  20230913045152   2023-09-13
# 1  3943  https://www.airbnb.com/rooms/3943  20230913045152   2023-09-13
# 2  4197  https://www.airbnb.com/rooms/4197  20230913045152   2023-09-13
# 3  4529  https://www.airbnb.com/rooms/4529  20230913045152   2023-09-13
# 4  4967  https://www.airbnb.com/rooms/4967  20230913045152   2023-09-13
#
#             source                                               name  \
# 0      city scrape  Home in Washington · ★4.64 · 1 bedroom · 1 bed...
# 1      city scrape  Townhouse in Washington · ★4.83 · 1 bedroom · ...
# 2      city scrape  Home in Washington · ★4.85 · 1 bedroom · 1 bed...
# 3      city scrape  Home in Washington · ★4.66 · 1 bedroom · 1 bed...
# 4  previous scrape  Home in Washington · ★4.74 · 1 bedroom · 1 bed...
#
#                                          description  \
# 0  IMPORTANT NOTES<br />* Carefully read and be s...
# ...

# %%
# print header names
print(df.columns)
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'source', 'name',
#        'description', 'neighborhood_overview', 'picture_url', 'host_id',
#        'host_url', 'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_acceptance_rate',
#        'host_is_superhost', 'host_thumbnail_url', 'host_picture_url',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'property_type', 'room_type', 'accommodates', 'bathrooms',
#        'bathrooms_text', 'bedrooms', 'beds', 'amenities', 'price',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
# ...

# %%
# build initial listings df
listings_df = df[["id", "name", "description", "listing_url", "neighborhood_overview", "picture_url", "neighbourhood", "neighbourhood_cleansed", "latitude", "longitude", "property_type", "room_type", "accommodates", "bathrooms_text", "bedrooms", "beds", "price", "license"]]
listings_df.head()
# Out:
#      id                                               name  \
# 0  3686  Home in Washington · ★4.64 · 1 bedroom · 1 bed...
# 1  3943  Townhouse in Washington · ★4.83 · 1 bedroom · ...
# 2  4197  Home in Washington · ★4.85 · 1 bedroom · 1 bed...
# 3  4529  Home in Washington · ★4.66 · 1 bedroom · 1 bed...
# 4  4967  Home in Washington · ★4.74 · 1 bedroom · 1 bed...
#
#                                          description  \
# 0  IMPORTANT NOTES<br />* Carefully read and be s...
# 1  You will be staying in high ceiling  bedroom w...
# 2  This is the middle bedroom upstairs in a resto...
# 3  This is  large private  bedroom with plenty of...
# 4  <b>The space</b><br />Hello, my name is Seveer...
#
#                          listing_url  \
# 0  https://www.airbnb.com/rooms/3686
# 1  https://www.airbnb.com/rooms/3943
# 2  https://www.airbnb.com/rooms/4197
# 3  https://www.airbnb.com/rooms/4529
# 4  https://www.airbnb.com/rooms/4967
#
# ...

# %%
len(listings_df)
# Out:
# 6705

# %%
len(df)
# Out:
# 6705

# %%
# rename id column to listing_id
listings_df.rename(columns={"id": "listing_id"}, inplace=True)
listings_df.head()
# Out:
# C:\Users\johbr\AppData\Local\Temp\ipykernel_21708\1181363841.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_df.rename(columns={"id": "listing_id"}, inplace=True)
#    listing_id                                               name  \
# 0        3686  Home in Washington · ★4.64 · 1 bedroom · 1 bed...
# 1        3943  Townhouse in Washington · ★4.83 · 1 bedroom · ...
# 2        4197  Home in Washington · ★4.85 · 1 bedroom · 1 bed...
# 3        4529  Home in Washington · ★4.66 · 1 bedroom · 1 bed...
# 4        4967  Home in Washington · ★4.74 · 1 bedroom · 1 bed...
#
#                                          description  \
# 0  IMPORTANT NOTES<br />* Carefully read and be s...
# 1  You will be staying in high ceiling  bedroom w...
# ...

# %%
# check data types
listings_df.dtypes
# Out:
# listing_id                  int64
# name                       object
# description                object
# listing_url                object
# neighborhood_overview      object
# picture_url                object
# neighbourhood              object
# neighbourhood_cleansed     object
# latitude                  float64
# longitude                 float64
# property_type              object
# room_type                  object
# accommodates                int64
# bathrooms_text             object
# bedrooms                  float64
# beds                      float64
# price                      object
# license                    object
# dtype: object

# %%
# remove $ from price column, convert to float
listings_df["price"] = listings_df["price"].str.replace("$", "").str.replace(",", "").astype(float)
# Out:
# C:\Users\johbr\AppData\Local\Temp\ipykernel_21708\2248875180.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   listings_df["price"] = listings_df["price"].str.replace("$", "").str.replace(",", "").astype(float)

# %%
listings_df.dtypes
# Out:
# listing_id                  int64
# name                       object
# description                object
# listing_url                object
# neighborhood_overview      object
# picture_url                object
# neighbourhood              object
# neighbourhood_cleansed     object
# latitude                  float64
# longitude                 float64
# property_type              object
# room_type                  object
# accommodates                int64
# bathrooms_text             object
# bedrooms                  float64
# beds                      float64
# price                     float64
# license                    object
# dtype: object

# %%
# save listings_df to csv
listings_df.to_csv("./listings_cleaned.csv", index=False)
